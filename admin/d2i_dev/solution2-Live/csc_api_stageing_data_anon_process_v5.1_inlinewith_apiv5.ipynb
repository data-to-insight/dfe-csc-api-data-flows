# %%
# Script: csc_api_stageing_data_anon_process_v0.0.0
# Author: D2I 



# Extracts the contents of HDM_Local.ssd_api_data_staging (should already include hashed change tracking column data etc). 
# It takes each json record from ssd_api_data_staging.json_payload and applies an anonymisation process to it, before duplicating 
# the entire table structure and (anon)data into HDM_Local.ssd_development.ssd_api_data_staging**_anon** 
# (if this test table already exists that copy will be dropped not truncated during this process).

# !! Script cannot be run from within Git/Spaces. 
# This script must be run locally(Anaconda/Python), within trusted environmemnt with ability to connect direct to CMS DB.  

# The Live process can take a while, obv dependent on data volume and connection capacity. 
# Expect to wait ~15mins start to end. E.g. "script completed in 837.49 seconds (13.96 minutes)".

# Current process anons the following fields:
# - all id's incl. child (maintains duplication of entries with new hashed vals if same id exists, e.g. repeat workers)
# - all dates, incl. dob (random but for someone aged 10-21yrs)
# - all start and end dates (randomises start-end dates but maintains approx interval for data consistency)
# - ethnicity (random from DfE returns defined list)
# - sex (random from DfE list of 3)
# - postcode (random generated uk code)
# -- and more, a full list is dynamically output during processing for full transparency. 
# **ENSURE THAT YOU VERIFY your expectations against the output list produced during the processing**. 

# **Note regarding ID/Data security:**
# Within this process: 
#             - names are replaced entirely with fake names (or a 'SSD_PH' string value)
#             - all ID's (person and worker) are hashed (but not salted), - deterministic one-way process and  
#             - in combination with the replacement of all date values with generated dates, disabilities, and ethnicity. 
# It would be computationally impossible to regenerate any persons natural|source data from the anonimised data. 


# %pip install Faker

import pyodbc
import hashlib
import random
from datetime import datetime, timedelta
from faker import Faker
import json
import time  
import random
import pandas as pd 


# enable use of subset(s) of source data to minimise/give option on testing data in use
# Define query type: 'all', 'top_X' (e.g., 'top_100'), or 'random_X' (e.g., 'random_100')
query_mode = "all"  # Options: "all", "top_100", "random_50"



# generating random pcodes
faker = Faker("en_GB")

# db connection details
CONN_DETAILS = {
    "driver": "{SQL Server}",
    "server": "ESLLREPORTS04V",
    "database": "HDM_Local",
    "trusted_connection": "yes"
}


def extract_all_keys(json_obj, parent_key=""):
    """Recursively extract all keys from nested JSON structure, used to cross-check what has/has not been anonymised"""
    keys = set()
    
    if isinstance(json_obj, dict):
        for key, value in json_obj.items():
            full_key = f"{parent_key}.{key}" if parent_key else key
            keys.add(full_key)
            keys.update(extract_all_keys(value, full_key))  # Recursively get keys

    elif isinstance(json_obj, list):
        for item in json_obj:
            keys.update(extract_all_keys(item, parent_key))  # Recursively handle lists
    
    return keys


def normalise_keys(data):
    """
    normalise all keys in a nested dictionary or list to lowercase
    """
    if isinstance(data, dict):
        return {key.lower(): normalise_keys(value) for key, value in data.items()}
    elif isinstance(data, list):
        return [normalise_keys(item) for item in data]
    else:
        return data

def hash_id(value, max_length=36):
    """create deterministic hash truncated to max_length. Usually 36, but some at 12, 13"""
    return hashlib.sha256(value.encode("utf-8")).hexdigest()[:max_length]


def normalise_dob(dob_str):
    """
    Return a realistic anonymised DoB.
    If the input is a known placeholder (like '1900-01-01'), generate a new one.
    """
    if dob_str in ["1900-01-01", "", None]:
        return generate_random_dob()
    return dob_str

def generate_random_dob():
    """
    Generate a realistic random date of birth for a person aged between 10 and 21 years.
    Returned as a string in YYYY-MM-DD format.
    """
    today = datetime.today()
    years_ago = random.uniform(10, 21)  # Float for better randomness
    random_days = int(years_ago * 365.25)
    random_date = today - timedelta(days=random_days)
    return random_date.strftime("%Y-%m-%d")


def random_date_after(base_date, min_years=1, max_years=10):
    """
    Generate a random date that is AFTER a given base date (i.e. DoB).
    Ensures a logical timeline, e.g., preventing worker/contact related dates before birth.
    """
    base_date_obj = parse_date_safe(base_date)  # Use safe parser
    days_ahead = random.randint(min_years * 365, max_years * 365)
    new_date = base_date_obj + timedelta(days=days_ahead)
    return new_date.strftime("%Y-%m-%d")


def parse_date_safe(date_input):
    """Convert various input formats to datetime object."""
    if isinstance(date_input, datetime):
        return date_input
    elif isinstance(date_input, str):
        date_str = date_input.split("T")[0]  # Strip time if present
        try:
            return datetime.strptime(date_str, "%Y-%m-%d")
        except ValueError:
            raise ValueError(f"Unrecognised date string format: {date_input}")
    else:
        raise TypeError(f"Expected str or datetime, got {type(date_input)}")

def randomise_date_with_interval(start_date, end_date, interval_range=10):
    """Randomise dates but preserve interval and avoiding future dates."""
    start_date_obj = parse_date_safe(start_date)
    end_date_obj = parse_date_safe(end_date)

    delta_days = (end_date_obj - start_date_obj).days

    # new start date, ensure it doesn't exceed today
    today = datetime.today()
    new_start_date = start_date_obj + timedelta(days=random.randint(-interval_range, interval_range))
    new_start_date = min(new_start_date, today)

    # new end date relative to new start date
    new_end_date = new_start_date + timedelta(days=delta_days)
    new_end_date = min(new_end_date, today)


    
    # DEBUG | TEMPORARY - Force both dates to day = 1 (so i can easily confirm in any outputs)
    new_start_date = new_start_date.replace(day=1)
    new_end_date = new_end_date.replace(day=1)


    
    return new_start_date.strftime("%Y-%m-%d"), new_end_date.strftime("%Y-%m-%d")


def random_ethnicity():
    """generate random ethnicity from the specified list"""
    return random.choice(
        [ 
            "WBRI", "WIRI", "WIRT", "WROM", "WOTH", "MWBC", "MWBA", "MWAS", "MOTH", 
            "AIND", "APKN", "ABAN", "AOTH", "BCRB", "BAFR", "BOTH", "CHNE", "OOTH", 
            "REFU", "NOBT"
        ]
    )

def random_sex():
    """generate random sex value (m, f, u)"""
    return random.choice(["M", "F", "U"])

def random_postcode():
    """generate random uk postcode"""
    return faker.postcode()



def extract_all_paths(data, prefix=""):
    """
    Recursively extract all possible dot-separated key paths from nested dicts/lists.
    """
    paths = set()
    if isinstance(data, dict):
        for key, value in data.items():
            full_key = f"{prefix}.{key}" if prefix else key
            paths.add(full_key)
            paths.update(extract_all_paths(value, full_key))
    elif isinstance(data, list):
        for item in data:
            paths.update(extract_all_paths(item, prefix))
    return paths



def audit_json_structure(records):
    print("\n🔍 Running JSON structure audit for nested fields...")

    misplaced_fields = ["uasc_flag", "uasc_end_date"]
    violations = []

    for i, record in enumerate(records):
        try:
            data = json.loads(record["json_payload"]) if isinstance(record["json_payload"], str) else record["json_payload"]
            child_details = data.get("child_details", {})

            for field in misplaced_fields:
                # Check if field exists at root level
                if field in data:
                    violations.append((i + 1, field, "❌ Found at root level"))
                # Check if it's missing entirely
                elif field not in child_details:
                    violations.append((i + 1, field, "⚠️ Missing from child_details"))

        except Exception as e:
            violations.append((i + 1, "⚠️ Error", str(e)))

    if violations:
        print("\n⚠️ Structural Issues Detected:\n")
        for rec in violations:
            print(f"Record {rec[0]:>3} | Field: {rec[1]:<20} | Issue: {rec[2]}")
    else:
        print("✅ All records have expected nested fields in the correct place.\n")


import json
from collections.abc import Mapping

def merge_structures(base, new):
    """
    Recursively merge keys from `new` into `base`, keeping default placeholder values.
    """
    for key, value in new.items():
        if key not in base:
            base[key] = normalise_value(value)
        elif isinstance(value, Mapping) and isinstance(base[key], Mapping):
            merge_structures(base[key], value)
        elif isinstance(value, list) and isinstance(base[key], list) and value and isinstance(value[0], Mapping):
            # Handle lists of dicts (e.g., sdq_assessments)
            if not base[key]:
                base[key].append({})
            merge_structures(base[key][0], value[0])
    return base

def normalise_value(value):
    """
    Generate a placeholder based on json value's type.
    """
    if isinstance(value, str):
        return ""
    elif isinstance(value, bool):
        return False
    elif isinstance(value, int):
        return 0
    elif isinstance(value, float):
        return 0.0
    elif isinstance(value, list):
        return [""] if value and isinstance(value[0], str) else []
    elif isinstance(value, dict):
        return merge_structures({}, value)
    return ""





## Pull the raw identifiable data from the source db table

# log the run time, as it takes a while
script_start_time = time.time()

# connect to db
try:
    connection_start_time = time.time()
    connection = pyodbc.connect(
        f"DRIVER={CONN_DETAILS['driver']};SERVER={CONN_DETAILS['server']};DATABASE={CONN_DETAILS['database']};Trusted_Connection={CONN_DETAILS['trusted_connection']};"
    )
    connection_time = time.time() - connection_start_time
    print(f"connected to database successfully in {connection_time:.2f} seconds.")
except pyodbc.Error as e:
    print(f"database connection failed: {e}")
    raise

cursor = connection.cursor()


# enable use of subset(s) of source data to minimise/give option on testing data in use
try:
    # Start fetch timer
    fetch_start_time = time.time()

    # dynamically based on mode
    if query_mode == "all":
        # la_child_id_list = ["129221", "102228", "102191"]
        # sql_query = f"SELECT * FROM ssd_api_data_staging WHERE person_id IN ({', '.join(f"'{id}'" for id in la_child_id_list)})"
        sql_query = f"SELECT * FROM ssd_api_data_staging"

    # top x records
    elif query_mode.startswith("top_"):
        limit = int(query_mode.split("_")[1])  # numeric value from 'top_X'
        sql_query = f"SELECT TOP {limit} * FROM ssd_api_data_staging"

    # random x records
    elif query_mode.startswith("random_"):
        limit = int(query_mode.split("_")[1])  # numeric value from 'random_X'
        sql_query = f"SELECT TOP {limit} * FROM ssd_api_data_staging ORDER BY NEWID()"

    else:
        raise ValueError("Invalid query_mode. Use 'all', 'top_X', or 'random_X'.")

    
    cursor.execute(sql_query)
    rows = cursor.fetchall() # db raw data records ready for processing
    column_names = [desc[0] for desc in cursor.description]  # Get col names

    # Calc fetch time
    fetch_time = time.time() - fetch_start_time
    print(f"Fetched {len(rows)} records from raw source ssd_api_data_staging in {fetch_time:.2f} seconds using query: {sql_query}")

except pyodbc.Error as e:
    print(f"Error fetching records: {e}")
    raise

## END Pull the raw identifiable data from the source db table




processed_data = []
anonymised_attributes = set() # track anonymised attributes, make it explicit on run which fields have been anonymised! 
all_original_keys = set() # Extract all keys BEFORE anonymisation

# process timer
processing_start_time = time.time()








## process records/raw identifiable data in memory

# json structure check(s)
audit_json_structure(rows)


# ✅ Store original and anonymised records for comparison
original_records = []
anonymised_records = []
schema_structure = {}


# ✅ Process records in memory
for i, row in enumerate(rows):

    record = dict(zip(column_names, row))  # Convert row to dictionary - incoming data as : (0, "123", '{"la_child_id":"1","child_details":{...}}')
    record_id = record["id"]
    person_id = record["person_id"]
    json_payload = json.loads(record["json_payload"])

    json_payload = normalise_keys(json_payload)  # Normalise keys

    
    ## Construct from available data/record unified schema with placeholder values
    # ✅ Call schema builder (on dict)
    merge_structures(schema_structure, json_payload)

    # ✅ schema_structure grows over iterations(not all records have complete struct)
    # ✅ Only print schema at last record
    if i == len(rows) - 1:
        # ✅ Add fixed top-level keys after final merge
        schema_structure["la_child_id"] = ""
        schema_structure["mis_child_id"] = ""
        
        # ✅ Wrap the final schema in a list
        final_schema_array = [schema_structure]
        
        # ✅ Output once, at the end
        print(json.dumps(final_schema_array, indent=2))

    ## END sample structure building
    

    
    # ✅ Store the original record for later comparison
    original_records.append(json.dumps(json_payload, indent=2))  # Keep JSON structure for readability


    try:
        # --- ✅ Anonymisation Process ---

        # --- ✅ Child details block ---    
        child_details = json_payload.get("child_details", {})
    
        # --- ✅ Replace First Name and Surname ---
        child_details["first_name"] = "SSH_PH"
        child_details["surname"] = "SSD_PH"
        # RE-implement later. For now using SSH_PH to increase visibility on anon-record processing
        # json_payload["child_details"]["surname"] = faker.last_name()
        # json_payload["child_details"]["first_name"] = faker.first_name()
        
        anonymised_attributes.update(["child_details.first_name", "child_details.surname"])
    
        # --- ✅ Anonymise Top-Level Fields ---
        json_payload["la_child_id"] = hash_id(json_payload.get("la_child_id", ""), max_length=36)
        anonymised_attributes.add("la_child_id")
    
        json_payload["mis_child_id"] = hash_id(json_payload.get("mis_child_id", ""), max_length=36)
        anonymised_attributes.add("mis_child_id")
    
        # --- ✅ Anonymise child_details Fields ---
        dob = child_details.get("date_of_birth")
        anon_dob = normalise_dob(dob)
        child_details["date_of_birth"] = anon_dob
        anonymised_attributes.add("child_details.date_of_birth")
    
        child_details["expected_date_of_birth"] = random_date_after(datetime.today(), min_years=0, max_years=1)
        anonymised_attributes.add("child_details.expected_date_of_birth")
    
        child_details["sex"] = random_sex()
        child_details["ethnicity"] = random_ethnicity()
        child_details["postcode"] = random_postcode()
        anonymised_attributes.update(["child_details.sex", "child_details.ethnicity", "child_details.postcode"])
    
        # --- ✅ Anonymise Disabilities ---
        num_disabilities = random.randint(0, 5)
        child_details["disabilities"] = random.sample(
            ["NONE", "MOB", "HAND", "PC", "INC", "COMM", "LD", "HEAR", "VIS", "BEH", "CON", "AUT", "DDA"],
            num_disabilities
        )
        anonymised_attributes.add("child_details.disabilities")
    
        # --- ✅ Anonymise UASC Flags ---
        child_details["uasc_flag"] = random.choice([True, False])
        child_details["uasc_end_date"] = random_date_after(datetime.today(), min_years=0, max_years=1)
        anonymised_attributes.update(["child_details.uasc_flag", "child_details.uasc_end_date"])
    
        # --- ✅ Anonymise Unique Pupil Numbers ---
        if "unique_pupil_number" in child_details:
            child_details["unique_pupil_number"] = hash_id(child_details["unique_pupil_number"], max_length=13)
            anonymised_attributes.add("child_details.unique_pupil_number")
    
        if "former_unique_pupil_number" in child_details:
            child_details["former_unique_pupil_number"] = hash_id(child_details["former_unique_pupil_number"], max_length=13)
            anonymised_attributes.add("child_details.former_unique_pupil_number")
    
        # ✅ Replace child_details in case you reassign it
        json_payload["child_details"] = child_details


        

        # --- ✅ Anonymise Health & Wellbeing (Inside Social Care Episodes) ---
        for wellbeing in json_payload.get("health_and_wellbeing", {}).get("sdq_assessments", []):      
            if "date" in wellbeing: #
                wellbeing["date"] = random_date_after(anon_dob, min_years=4, max_years=16)
                anonymised_attributes.add("health_and_wellbeing.sdq_assessments.sdq_date")

            if "score" in wellbeing: #
                # where: Normal| Borderline| Cause for concern - 0-13 |14-16 |17-40 
                wellbeing["score"] = random.randint(1, 40)
                anonymised_attributes.add("health_and_wellbeing.sdq_assessments.sdq_score")

    
        
        # --- ✅ Anonymise Education, Health & Care Plans ---
        for ehc_plan in json_payload.get("education_health_care_plans", []):
            if "education_health_care_plan_id" in ehc_plan:
                ehc_plan["education_health_care_plan_id"] = hash_id(ehc_plan["education_health_care_plan_id"], max_length=36)
                anonymised_attributes.add("education_health_care_plans.education_health_care_plan_id")

            for date_field in ["request_received_date", "request_outcome_date", "assessment_outcome_date", "plan_start_date"]:
                if date_field in ehc_plan:
                    ehc_plan[date_field] = random_date_after(anon_dob, min_years=3, max_years=18)  # Date within childhood
                    anonymised_attributes.add(f"education_health_care_plans.{date_field}")


        
        # --- ✅ Anonymise Social Care Episodes ---
        episodes = json_payload.get("social_care_episodes")
        
        if isinstance(episodes, list):
            print(f"✅ Record {record_id}: 'social_care_episodes' contains list with {len(episodes)} episodes.")
            
            for episode in episodes:
                if "social_care_episode_id" in episode:
                    episode["social_care_episode_id"] = hash_id(episode["social_care_episode_id"], max_length=36)
                    anonymised_attributes.add("social_care_episodes.social_care_episode_id")
    

                referral_date = episode.get("referral_date")
                closure_date = episode.get("closure_date")
    
                if referral_date and closure_date:
                    episode["referral_date"], episode["closure_date"] = randomise_date_with_interval(referral_date, closure_date)
                    anonymised_attributes.update(["social_care_episodes.referral_date", "social_care_episodes.closure_date"])
                elif referral_date:
                    episode["referral_date"] = randomise_date_with_interval(referral_date, referral_date)[0]
                    anonymised_attributes.add("social_care_episodes.referral_date")
    
                episode["referral_source"] = random.choice(["1A", "1B", "2A", "2B", "3A", "3B"])
                episode["closure_reason"] = random.choice(["RC1", "RC2", "RC3", "RC4", "RC5"])
                episode["referral_no_further_action_flag"] = random.choice([True, False])  
                anonymised_attributes.update(["social_care_episodes.referral_source", "social_care_episodes.closure_reason", "social_care_episodes.referral_no_further_action_flag"])
    
    
                # --- ✅ Anonymise Care Worker Details (Must be inside social_care_episodes) ---
                for worker in episode.get("social_worker_details", []):  # instead of care_worker_details
                    if "worker_id" in worker:
                        worker["worker_id"] = hash_id(worker["worker_id"], max_length=12)  # Note hash length is field specific
                        anonymised_attributes.add("social_care_episodes.social_worker_details.worker_id")
                
                    start_date = worker.get("start_date")
                    end_date = worker.get("end_date")
                
                    if start_date and end_date:
                        worker["start_date"], worker["end_date"] = randomise_date_with_interval(start_date, end_date)
                        anonymised_attributes.update(["social_care_episodes.social_worker_details.start_date", "social_care_episodes.social_worker_details.end_date"])
                    elif start_date:
                        worker["start_date"] = randomise_date_with_interval(start_date, start_date)[0]
                        anonymised_attributes.add("social_care_episodes.social_worker_details.start_date")
                    elif end_date:
                        worker["end_date"] = randomise_date_with_interval(end_date, end_date)[0]
                        anonymised_attributes.add("social_care_episodes.social_worker_details.end_date")
    
            
                
                # --- ✅ Anonymise Child and Family Assessments ---
                for assessment in episode.get("child_and_family_assessments", []):
                    if "child_and_family_assessment_id" in assessment:
                        assessment["child_and_family_assessment_id"] = hash_id(assessment["child_and_family_assessment_id"], max_length=36)
                        anonymised_attributes.add("child_and_family_assessments.child_and_family_assessment_id")
        
                    start_date = assessment.get("start_date")
                    authorisation_date = assessment.get("authorisation_date")
        
                    if start_date and authorisation_date:
                        assessment["start_date"], assessment["authorisation_date"] = randomise_date_with_interval(start_date, authorisation_date)
                        anonymised_attributes.update(["child_and_family_assessments.start_date", "child_and_family_assessments.authorisation_date"])
                    elif start_date:
                        assessment["start_date"] = randomise_date_with_interval(start_date, start_date)[0]
                        anonymised_attributes.add("child_and_family_assessments.start_date")
                    elif authorisation_date:
                        assessment["authorisation_date"] = randomise_date_with_interval(authorisation_date, authorisation_date)[0]
                        anonymised_attributes.add("child_and_family_assessments.authorisation_date")
        
                    # ✅ Fixed: Added missing `factors` anonymisation / Max length 3
                    assessment["factors"] = random.sample(
                        [
                            "1A", "1B", "1C", "2A", "2B", "2C", "3A", "3B", "3C", "4A", "4B", "4C",
                            "5A", "5B", "5C", "6A", "6B", "6C", "7A", "8B", "8C", "8D", "8E", "8F",
                            "9A", "10A", "11A", "12A", "13A", "14A", "15A", "16A", "17A", "18B",
                            "18C", "19B", "19C", "20", "21", "22A", "23A", "24A"
                        ],
                        random.randint(1, 5)  
                    )
                    anonymised_attributes.add("child_and_family_assessments.factors")
        
        
                
                # Anonymise child_in_need_plans
                for plan in episode.get("child_in_need_plans", []):
                    
                    if "child_in_need_plan_id" in plan:
                        plan["child_in_need_plan_id"] = hash_id(plan["child_in_need_plan_id"], max_length=36)
                        anonymised_attributes.add("child_in_need_plans.child_in_need_plan_id")
        
                    start_date = plan.get("start_date", "").split("T")[0]
                    end_date = plan.get("end_date", "").split("T")[0]
        
                    if start_date and end_date:
                        plan["start_date"], plan["end_date"] = randomise_date_with_interval(start_date, end_date)
                        anonymised_attributes.add("child_in_need_plans.start_date")
                        anonymised_attributes.add("child_in_need_plans.end_date")
        
        
        
                # --- ✅ Anonymise Section 47 Assessments ---
                for assessment in episode.get("section_47_assessments", []):
                    if "section_47_assessment_id" in assessment:
                        assessment["section_47_assessment_id"] = hash_id(assessment["section_47_assessment_id"], max_length=36)
                        anonymised_attributes.add("section_47_assessments.section_47_assessment_id")
        
                    start_date = assessment.get("start_date")
                    icpc_date = assessment.get("icpc_date")
                    end_date = assessment.get("end_date")
        
                    # ✅ Anonymise start_date, icpc_date, and end_date if they exist
                    if start_date and end_date:
                        assessment["start_date"], assessment["end_date"] = randomise_date_with_interval(start_date, end_date)
                        anonymised_attributes.update(["section_47_assessments.start_date", "section_47_assessments.end_date"])
                    elif start_date:
                        assessment["start_date"] = randomise_date_with_interval(start_date, start_date)[0]
                        anonymised_attributes.add("section_47_assessments.start_date")
                    elif end_date:
                        assessment["end_date"] = randomise_date_with_interval(end_date, end_date)[0]
                        anonymised_attributes.add("section_47_assessments.end_date")
        
                    if icpc_date:
                        assessment["icpc_date"] = randomise_date_with_interval(icpc_date, icpc_date)[0]
                        anonymised_attributes.add("section_47_assessments.icpc_date")
        
                    # ✅ Anonymise icpc_required_flag (randomly set to True or False)
                    assessment["icpc_required_flag"] = random.choice([True, False])
                    anonymised_attributes.add("section_47_assessments.icpc_required_flag")
        
        
        
                # --- ✅ Anonymise Child Protection Plans ---
                for plan in episode.get("child_protection_plans", []):
                    if "child_protection_plan_id" in plan:
                        plan["child_protection_plan_id"] = hash_id(plan["child_protection_plan_id"], max_length=36)
                        anonymised_attributes.add("child_protection_plans.child_protection_plan_id")
        
                    start_date = plan.get("start_date")
                    end_date = plan.get("end_date")
        
                    # ✅ Anonymise start_date and end_date if they exist
                    if start_date and end_date:
                        plan["start_date"], plan["end_date"] = randomise_date_with_interval(start_date, end_date)
                        anonymised_attributes.update(["child_protection_plans.start_date", "child_protection_plans.end_date"])
                    elif start_date:
                        plan["start_date"] = randomise_date_with_interval(start_date, start_date)[0]
                        anonymised_attributes.add("child_protection_plans.start_date")
                    elif end_date:
                        plan["end_date"] = randomise_date_with_interval(end_date, end_date)[0]
                        anonymised_attributes.add("child_protection_plans.end_date")
        
        
                
        
                # --- ✅ Anonymise Child Looked After Placements ---
                for placement in episode.get("child_looked_after_placements", []):
                    if "child_looked_after_placement_id" in placement:
                        placement["child_looked_after_placement_id"] = hash_id(placement["child_looked_after_placement_id"], max_length=36)
                        anonymised_attributes.add("child_looked_after_placements.child_looked_after_placement_id")
        
                    start_date = placement.get("start_date")
                    end_date = placement.get("end_date")
        
                    # ✅ Randomise start and end dates while maintaining intervals
                    if start_date and end_date:
                        placement["start_date"], placement["end_date"] = randomise_date_with_interval(start_date, end_date)
                        anonymised_attributes.update(["child_looked_after_placements.start_date", "child_looked_after_placements.end_date"])
                    elif start_date:
                        placement["start_date"] = randomise_date_with_interval(start_date, start_date)[0]
                        anonymised_attributes.add("child_looked_after_placements.start_date")
                    elif end_date:
                        placement["end_date"] = randomise_date_with_interval(end_date, end_date)[0]
                        anonymised_attributes.add("child_looked_after_placements.end_date")
        
                    # ✅ Replace categorical fields with valid random codes
                    placement["start_reason"] = random.choice(["S", "M", "P", "C"]) 
                    placement["placement_type"] = random.choice(["K1", "K2", "R1", "R2"])
                    placement["end_reason"] = random.choice(["E1", "E2", "E3", "E4"])
                    placement["change_reason"] = random.choice(["CHILD", "CARER", "ORG", "OTHER"])
                    placement["postcode"] = random_postcode()  # Random / generated postcode

                    # add to tracking
                    anonymised_attributes.update([
                        "child_looked_after_placements.start_reason",
                        "child_looked_after_placements.placement_type",
                        "child_looked_after_placements.end_reason",
                        "child_looked_after_placements.change_reason",
                        "child_looked_after_placements.postcode"
                    ])

        ## turning this off to avoid verbose output. Otherwise hits for each record with no epiodes logged
        # else:
        #     print(f"⚠️ Record {record_id}: 'social_care_episodes' is missing or not a list (got {type(episodes)}) — skipping.")


        
        # --- ✅ Anonymise Adoption Details ---
        if "adoption" in episode:
            adoption = episode["adoption"]

            for date_field in ["initial_decision_date", "matched_date", "placed_date"]:
                if date_field in adoption:
                    adoption[date_field] = random_date_after(anon_dob, min_years=1, max_years=18)
                    anonymised_attributes.add(f"adoption.{date_field}")


        
        # --- ✅ Anonymise Care Leavers (At Root Level) ---
        if "care_leavers" in json_payload:
            care_leaver = json_payload["care_leavers"]
        
            if "contact_date" in care_leaver:
                care_leaver["contact_date"] = random_date_after(anon_dob, min_years=14, max_years=30)  
                anonymised_attributes.add("care_leavers.contact_date")
        
            if "activity" in care_leaver:
                care_leaver["activity"] = random.choice(["F1", "P1", "F2", "P2", "F4", "P4", "F5", "P5", "G4", "G5", "G6"])
                anonymised_attributes.add("care_leavers.activity")
        
            if "accommodation" in care_leaver:
                care_leaver["accommodation"] = random.choice(["B", "C", "D", "E", "G", "H", "K", "R", "S", "T", "U", "V", "W", "X", "Y", "Z"])
                anonymised_attributes.add("care_leavers.accommodation")



    
    except Exception as e:
        print(f"⚠️ ERROR: Failed to process record {record_id} - {e}")
        # json_payload = {"error": f"❌ ERROR Processing Record {record_id}"}  # ✅ Ensure something is stored


    # ✅ Ensure anonymised record is ALWAYS added
    anonymised_records.append(json.dumps(json_payload, indent=2))


    if isinstance(record, dict):
        record["person_id"] = hash_id(person_id) if person_id else None
        record["json_payload"] = json.dumps(json_payload)
        processed_data.append(tuple(record.values()))
    else:
        print(f"⚠️ Skipping record {record_id} - expected dict, got {type(record)}: {record}")



    
processing_time = time.time() - processing_start_time
print(f"\n\nprocessed-anon extracted records in {processing_time:.2f} seconds.")
print(f"\nsending back to the ssd_api_data_staging_anon table on db now... ")

# create new ANON table fo api tests to hit
try:
    table_creation_start_time = time.time()
    # Note: The below table def differs to the source one, and therefore the following should not be pre-set:
    # (auto)PK value, any default status values should not be defined as all later copied accross.
    cursor.execute("DROP TABLE IF EXISTS ssd_api_data_staging_anon")
    cursor.execute("""
        CREATE TABLE ssd_api_data_staging_anon (
            id                      INT PRIMARY KEY,          
            person_id               NVARCHAR(48) NULL,              -- Link value (_person_id or equivalent)
            previous_json_payload   NVARCHAR(MAX) NULL,             -- Enable sub-attribute purge tracking
            json_payload            NVARCHAR(MAX) NULL,             -- JSON data payload
            partial_json_payload    NVARCHAR(MAX) NULL,         -- Reductive JSON data payload
            previous_hash           BINARY(32) NULL,                -- Previous hash of JSON payload
            current_hash            BINARY(32) NULL,                -- Current hash of JSON payload
            row_state               NVARCHAR(10) NULL,              -- Record state: New, Updated, Deleted, Unchanged
            last_updated            DATETIME NULL,                  -- Last update timestamp
            submission_status       NVARCHAR(50) NULL,              -- Status: pending, sent, error
            api_response            NVARCHAR(MAX) NULL,             -- API response or error messages
            submission_timestamp    DATETIME                        -- Timestamp on API submission
        )
    """)
    
    
    

    
    
    table_creation_time = time.time() - table_creation_start_time
    print(f"created new table ssd_api_data_staging_anon ready for data insertion in {table_creation_time:.2f} seconds.")
    print(f"\npreparing data for insertion now...")

except pyodbc.Error as e:
    print(f"error creating ssd_api_data_staging_anon table: {e}")
    raise

# bulk insert processed data
try:
    insert_start_time = time.time()
    column_placeholders = ", ".join(["?"] * len(column_names))
    insert_query = f"INSERT INTO ssd_api_data_staging_anon ({', '.join(column_names)}) VALUES ({column_placeholders})"
    cursor.executemany(insert_query, processed_data)
    insert_time = time.time() - insert_start_time
    print(f"inserted all processed records into ssd_api_data_staging_anon in {insert_time:.2f} seconds.")
except pyodbc.Error as e:
    print(f"error inserting data: {e}")
    raise

# commit db changes
commit_start_time = time.time()
connection.commit()
commit_time = time.time() - commit_start_time
print(f"\n\ncommitted all changes in {commit_time:.2f} seconds.")

# close connection
cursor.close()
connection.close()
print("database connection closed.")

# End timer
script_end_time = time.time()
total_time = script_end_time - script_start_time
total_time_minutes = total_time / 60

print(f"\nscript completed in {total_time:.2f} seconds ({total_time_minutes:.2f} minutes).")
# Out:
# connected to database successfully in 0.00 seconds.
# Fetched 4000 records from raw source ssd_api_data_staging in 1.80 seconds using query: SELECT * FROM ssd_api_data_staging
#
# 🔍 Running JSON structure audit for nested fields...
#
# ⚠️ Structural Issues Detected:
#
# Record   1 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record   2 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record   3 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record   4 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record   5 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record   6 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record   7 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record   8 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record   9 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  10 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  11 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  12 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  13 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  14 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  15 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  16 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  17 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  18 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  19 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  20 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  21 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  22 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  23 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  24 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  25 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  26 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  27 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  28 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  29 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  30 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  31 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  32 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  33 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  34 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  35 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  36 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  37 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  38 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  39 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  40 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  41 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  42 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  43 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  44 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  45 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  46 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  47 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  48 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  49 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  50 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  51 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  52 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  53 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  54 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  55 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  56 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  57 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  58 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  59 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  60 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  61 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  62 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  63 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  64 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  65 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  66 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  67 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  68 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  69 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  70 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  71 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  72 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  73 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  74 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  75 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  76 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  77 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  78 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  79 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  80 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  81 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  82 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  83 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  84 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  85 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  86 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  87 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  88 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  89 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  90 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  91 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  92 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  93 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  94 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  95 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  96 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  97 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  98 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record  99 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 100 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 101 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 102 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 103 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 104 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 105 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 106 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 107 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 108 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 109 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 110 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 111 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 112 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 113 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 114 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 115 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 116 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 117 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 118 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 119 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 120 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 121 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 122 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 123 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 124 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 125 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 126 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 127 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 128 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 129 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 130 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 131 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 132 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 133 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 134 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 135 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 136 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 137 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 138 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 139 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 140 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 141 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 142 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 143 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 144 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 145 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 146 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 147 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 148 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 149 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 150 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 151 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 152 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 153 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 154 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 155 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 156 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 157 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 158 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 159 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 160 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 161 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 162 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 163 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 164 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 165 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 166 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 167 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 168 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 169 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 170 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 171 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 172 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 173 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 174 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 175 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 176 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 177 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 178 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 179 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 180 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 181 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 182 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 183 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 184 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 185 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 186 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 187 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 188 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 189 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 190 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 191 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 192 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 193 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 194 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 195 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 196 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 197 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 198 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 199 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 200 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 201 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 202 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 203 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 204 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 205 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 206 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 207 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 208 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 209 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 210 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 211 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 212 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 213 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 214 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 215 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 216 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 217 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 218 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 219 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 220 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 221 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 222 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 223 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 224 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 225 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 226 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 227 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 228 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 229 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 230 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 231 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 232 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 233 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 234 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 235 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 236 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 237 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 238 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 239 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 240 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 241 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 242 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 243 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 244 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 245 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 246 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 247 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 248 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 249 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 250 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 251 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 252 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 253 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 254 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 255 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 256 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 257 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 258 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 259 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 260 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 261 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 262 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 263 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 264 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 265 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 266 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 267 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 268 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 269 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 270 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 271 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 272 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 273 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 274 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 275 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 276 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 277 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 278 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 279 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 280 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 281 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 282 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 283 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 284 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 285 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 286 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 287 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 288 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 289 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 290 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 291 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 292 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 293 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 294 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 295 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 296 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 297 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 298 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 299 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 300 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 301 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 302 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 303 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 304 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 305 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 306 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 307 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 308 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 309 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 310 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 311 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 312 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 313 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 314 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 315 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 316 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 317 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 318 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 319 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 320 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 321 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 322 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 323 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 324 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 325 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 326 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 327 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 328 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 329 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 330 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 331 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 332 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 333 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 334 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 335 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 336 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 337 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 338 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 339 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 340 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 341 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 342 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 343 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 344 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 345 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 346 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 347 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 348 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 349 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 350 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 351 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 352 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 353 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 354 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 355 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 356 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 357 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 358 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 359 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 360 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 361 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 362 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 363 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 364 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 365 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 366 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 367 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 368 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 369 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 370 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 371 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 372 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 373 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 374 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 375 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 376 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 377 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 378 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 379 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 380 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 381 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 382 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 383 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 384 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 385 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 386 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 387 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 388 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 389 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 390 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 391 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 392 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 393 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 394 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 395 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 396 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 397 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 398 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 399 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 400 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 401 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 402 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 403 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 404 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 405 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 406 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 407 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 408 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 409 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 410 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 411 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 412 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 413 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 414 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 415 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 416 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 417 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 418 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 419 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 420 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 421 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 422 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 423 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 424 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 425 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 426 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 427 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 428 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 429 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 430 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 431 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 432 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 433 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 434 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 435 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 436 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 437 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 438 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 439 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 440 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 441 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 442 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 443 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 444 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 445 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 446 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 447 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 448 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 449 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 450 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 451 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 452 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 453 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 454 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 455 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 456 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 457 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 458 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 459 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 460 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 461 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 462 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 463 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 464 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 465 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 466 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 467 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 468 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 469 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 470 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 471 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 472 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 473 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 474 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 475 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 476 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 477 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 478 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 479 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 480 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 481 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 482 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 483 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 484 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 485 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 486 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 487 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 488 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 489 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 490 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 491 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 492 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 493 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 494 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 495 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 496 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 497 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 498 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 499 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 500 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 501 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 502 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 503 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 504 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 505 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 506 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 507 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 508 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 509 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 510 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 511 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 512 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 513 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 514 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 515 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 516 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 517 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 518 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 519 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 520 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 521 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 522 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 523 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 524 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 525 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 526 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 527 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 528 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 529 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 530 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 531 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 532 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 533 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 534 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 535 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 536 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 537 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 538 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 539 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 540 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 541 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# Record 542 | Field: ⚠️ Error             | Issue: row indices must be integers, not str
# ...
# ✅ Record 3041: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3043: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3047: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3048: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3049: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3066: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3068: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3070: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3071: 'social_care_episodes' contains list with 2 episodes.
# ✅ Record 3074: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3075: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3104: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3106: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3110: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3111: 'social_care_episodes' contains list with 2 episodes.
# ✅ Record 3117: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3127: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3136: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3143: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3145: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3147: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3155: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3156: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3157: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3165: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3179: 'social_care_episodes' contains list with 3 episodes.
# ✅ Record 3181: 'social_care_episodes' contains list with 2 episodes.
# ✅ Record 3182: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3184: 'social_care_episodes' contains list with 2 episodes.
# ✅ Record 3187: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3194: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3195: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3197: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3204: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3209: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3222: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3223: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3226: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3233: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3238: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3239: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3242: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3243: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3245: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3249: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3254: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3256: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3259: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3260: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3267: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3270: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3276: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3278: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3282: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3290: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3299: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3300: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3306: 'social_care_episodes' contains list with 2 episodes.
# ✅ Record 3310: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3312: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3314: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3320: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3322: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3325: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3330: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3331: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3335: 'social_care_episodes' contains list with 3 episodes.
# ✅ Record 3347: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3350: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3353: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3355: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3357: 'social_care_episodes' contains list with 2 episodes.
# ✅ Record 3358: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3359: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3360: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3367: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3369: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3372: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3381: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3382: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3383: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3388: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3392: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3393: 'social_care_episodes' contains list with 2 episodes.
# ✅ Record 3396: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3398: 'social_care_episodes' contains list with 2 episodes.
# ✅ Record 3405: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3410: 'social_care_episodes' contains list with 2 episodes.
# ✅ Record 3414: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3426: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3434: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3435: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3436: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3437: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3454: 'social_care_episodes' contains list with 2 episodes.
# ✅ Record 3457: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3458: 'social_care_episodes' contains list with 2 episodes.
# ✅ Record 3459: 'social_care_episodes' contains list with 2 episodes.
# ✅ Record 3467: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3471: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3477: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3478: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3480: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3481: 'social_care_episodes' contains list with 3 episodes.
# ✅ Record 3493: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3494: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3495: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3496: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3501: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3510: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3513: 'social_care_episodes' contains list with 2 episodes.
# ✅ Record 3518: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3521: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3527: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3533: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3537: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3540: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3542: 'social_care_episodes' contains list with 2 episodes.
# ✅ Record 3543: 'social_care_episodes' contains list with 2 episodes.
# ✅ Record 3552: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3553: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3570: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3573: 'social_care_episodes' contains list with 2 episodes.
# ✅ Record 3579: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3583: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3596: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3615: 'social_care_episodes' contains list with 2 episodes.
# ✅ Record 3625: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3641: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3676: 'social_care_episodes' contains list with 2 episodes.
# ✅ Record 3680: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3681: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3694: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3695: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3696: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3697: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3699: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3703: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3709: 'social_care_episodes' contains list with 2 episodes.
# ✅ Record 3710: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3711: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3724: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3726: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3732: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3751: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3752: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3753: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3755: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3756: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3760: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3761: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3769: 'social_care_episodes' contains list with 2 episodes.
# ✅ Record 3772: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3773: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3774: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3790: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3791: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3799: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3811: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3812: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3826: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3867: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3868: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3871: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3886: 'social_care_episodes' contains list with 4 episodes.
# ✅ Record 3889: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3890: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3893: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3894: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3896: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3902: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3905: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3909: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3914: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3917: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3918: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3919: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3921: 'social_care_episodes' contains list with 2 episodes.
# ✅ Record 3926: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3934: 'social_care_episodes' contains list with 3 episodes.
# ✅ Record 3942: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3949: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3971: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3973: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3981: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3994: 'social_care_episodes' contains list with 1 episodes.
# ✅ Record 3999: 'social_care_episodes' contains list with 1 episodes.
# [
#   {
#     "la_child_id": "",
#     "mis_child_id": "",
#     "child_details": {
#       "first_name": "",
#       "surname": "",
#       "unique_pupil_number_unknown_reason": "",
#       "date_of_birth": "",
#       "sex": "",
#       "ethnicity": "",
#       "postcode": "",
#       "purge": false,
#       "unique_pupil_number": "",
#       "disabilities": [
#         ""
#       ],
#       "uasc_flag": "",
#       "former_unique_pupil_number": ""
#     },
#     "health_and_wellbeing": {
#       "purge": false
#     },
#     "social_care_episodes": [
#       {
#         "social_care_episode_id": "",
#         "referral_date": "",
#         "referral_source": "",
#         "closure_date": "",
#         "closure_reason": "",
#         "purge": false,
#         "social_worker_details": [
#           {
#             "worker_id": "",
#             "start_date": "",
#             "end_date": "",
#             "purge": false
#           }
#         ],
#         "child_and_family_assessments": [
#           {
#             "child_and_family_assessment_id": "",
#             "start_date": "",
#             "authorisation_date": "",
#             "factors": [
#               ""
#             ],
#             "purge": false
#           }
#         ],
#         "care_leavers": {
#           "purge": false,
#           "contact_date": "",
#           "activity": "",
#           "accommodation": ""
#         },
#         "child_looked_after_placements": [
#           {
#             "child_looked_after_placement_id": "",
#             "start_date": "",
#             "start_reason": "",
#             "end_date": "",
#             "end_reason": "",
#             "purge": false,
#             "placement_details": [
#               {
#                 "placement_id": "",
#                 "start_date": "",
#                 "placement_postcode": "",
#                 "placement_type": "",
#                 "end_date": "",
#                 "change_reason": ""
#               }
#             ]
#           }
#         ],
#         "section_47_assessments": [
#           {
#             "section_47_assessment_id": "",
#             "start_date": "",
#             "icpc_required_flag": "",
#             "icpc_date": "",
#             "end_date": "",
#             "purge": false
#           }
#         ],
#         "child_in_need_plans": [
#           {
#             "child_in_need_plan_id": "",
#             "start_date": "",
#             "end_date": "",
#             "purge": false
#           }
#         ],
#         "child_protection_plans": [
#           {
#             "child_protection_plan_id": "",
#             "start_date": "",
#             "end_date": "",
#             "purge": false
#           }
#         ],
#         "referral_no_further_action_flag": ""
#       }
#     ]
#   }
# ]
#
#
# processed-anon extracted records in 1.19 seconds.
#
# sending back to the ssd_api_data_staging_anon table on db now...
# created new table ssd_api_data_staging_anon ready for data insertion in 0.05 seconds.
#
# preparing data for insertion now...
# inserted all processed records into ssd_api_data_staging_anon in 123.56 seconds.
#
#
# committed all changes in 0.01 seconds.
# database connection closed.
#
# script completed in 126.65 seconds (2.11 minutes).
